# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
# %matplotlib widget

# %%
inventario = pd.read_excel("imports/MGGDATOS_Inventario.ods", engine="odf")
inventario[0:12]
# Out:
#       Estado Departamento                                             Nombre  \
# 0   Completo       ACCUEE                                 Acceso a los datos
# 1   Completo        ACPMN                                          Sigestein
# 2   Completo        AGPSA                      Registro vitícola comunitario
# 3   Completo        AGPSA  Registro de Sociedades Agrarias de Transformac...
# 4   Completo        AGPSA                       Sistema de gestión del PEPAC
# 5   Completo        AGPSA                       Sistema de gestión del POSEI
# 6   Completo        AGPSA                    Sistema de gestión del POSEICAN
# 7   Completo        AGPSA                    Sistema de gestión de Ganadería
# 8   Completo        AGPSA  Sistema de tramitación electrónica de procedim...
# 9   Completo        AGPSA  Sistema de gestión de parcelas agrícolas de Ca...
# 10  Completo        AGPSA  Sistema de información para la gestión de las ...
# ...

# %%
for row in inventario:
    print(row)
# Out:
# Estado
# Departamento
#  Nombre
# Código identificativo interno (CII)
# Finalidad
# Materia competencial
# DIR3 (centro directivo)
# UID de la persona responsable tecnológica
# UID de la persona responsable funcional
# Normativa (Juriscan)
# Observaciones
# Unnamed: 11
# Unnamed: 12
# Unnamed: 13
# Unnamed: 14

# %%
for index, row in inventario.iterrows():
    print(index, tuple(row), tuple(row))
    t = tuple(row)
    print(type(t))
    print(t[0])
    break
# Out:
# 0 ('Completo', 'ACCUEE', 'Acceso a los datos', 'MOODLE', 'Plataforma habilitada por la ACCUEE donde se le da acceso a los solicitantes a los datos.', 'Educación', 'A05003411', 'hgonort', 'rcrugon', nan, nan, nan, nan, nan, nan) ('Completo', 'ACCUEE', 'Acceso a los datos', 'MOODLE', 'Plataforma habilitada por la ACCUEE donde se le da acceso a los solicitantes a los datos.', 'Educación', 'A05003411', 'hgonort', 'rcrugon', nan, nan, nan, nan, nan, nan)
# <class 'tuple'>
# Completo

# %% [markdown]
# ## Equivalente al ``Select Estado from inventario``

# %%
inventario[0:1]
# Out:
#      Estado Departamento              Nombre  \
# 0  Completo       ACCUEE  Acceso a los datos
#
#   Código identificativo interno (CII)  \
# 0                              MOODLE
#
#                                            Finalidad Materia competencial   \
# 0  Plataforma habilitada por la ACCUEE donde se l...             Educación
#
#   DIR3 (centro directivo) UID de la persona responsable tecnológica  \
# 0               A05003411                                   hgonort
#
#   UID de la persona responsable funcional Normativa (Juriscan) Observaciones  \
# 0                                 rcrugon                  NaN           NaN
#
#   Unnamed: 11  Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0         NaN          NaN          NaN         NaN

# %%
inventario.keys()
# Out:
# Index(['Estado', 'Departamento', ' Nombre',
#        'Código identificativo interno (CII)', 'Finalidad',
#        'Materia competencial ', 'DIR3 (centro directivo)',
#        'UID de la persona responsable tecnológica',
#        'UID de la persona responsable funcional', 'Normativa (Juriscan)',
#        'Observaciones', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='str')

# %%
inventario[['Estado', 'Materia competencial ']].groupby('Materia competencial ').count()
# Out:
#                                           Estado
# Materia competencial
# Agricultura                                   22
# Bienestar Social                              28
# Comercio                                       5
# Consumo                                        2
# Contabilidad                                   3
# Cooperación al desarrollo                      1
# Cultura                                       52
# Educación                                     13
# Emergencias                                    5
# Energía                                        4
# Estadísticas                                   5
# Estrategia y organización administrativa       5
# Flora y Fauna                                  6
# Formación para el empleo                       5
# Ganadería                                      3
# Gestion documental integral                    1
# Gestión RRHH                                   6
# I+D+i                                         89
# ...

# %%
inventario.groupby('Estado').count()
# Out:
#                 Departamento   Nombre  Código identificativo interno (CII)  \
# Estado
# Completo                 211      211                                  211
# Eliminado                 62       62                                   18
# PTE. ORGANISMO           197      197                                  196
# Revisar                   28       28                                   28
#
#                 Finalidad  Materia competencial   DIR3 (centro directivo)  \
# Estado
# Completo              211                    211                      211
# Eliminado              18                     62                       62
# PTE. ORGANISMO        183                    197                      188
# Revisar                28                     28                       27
#
#                 UID de la persona responsable tecnológica  \
# Estado
# Completo                                              210
# Eliminado                                              18
# ...

# %%
df = pd.DataFrame({
        'label': ['A', 'B', 'C', 'A', 'B', 'C'],
        'value': [1, 2, 3, 4, 5, 6],
        })

# %%
df[['value', 'label']]
# Out:
#    value label
# 0      1     A
# 1      2     B
# 2      3     C
# 3      4     A
# 4      5     B
# 5      6     C

# %%
plt.style.use('ggplot')

# %%
x = np.linspace(0, 10, num=100)

# %%
y = np.sin(x)

# %%
# %matplotlib inline

plt.plot(x, y)

# %%
plt.plot(x, np.cos(x))
plt.plot(x, y)

# %%
d = {
        'one' : pd.Series([10, 20, 30, 40], index =['a', 'b', 'c', 'd']),
        'two' : pd.Series([10, 20, 30, 40], index =['a', 'b', 'c', 'd']),
    }
df = pd.DataFrame(d)
df
# Out:
#    one  two
# a   10   10
# b   20   20
# c   30   30
# d   40   40

# %%
d = {
        'one' : pd.Series([10, 20, 30, 40]),
        'two' : pd.Series([10, 20, 30, 40]),
    }
df = pd.DataFrame(d)
df
# Out:
#    one  two
# 0   10   10
# 1   20   20
# 2   30   30
# 3   40   40

# %%
d = pd.DataFrame({'a': [1, 2, 7], 'b': [3, 4, 21]})
d = d.assign(suma = d['a'] + d['b'])
d = d.assign(media=d.suma/2)
d
# Out:
#    a   b  suma  media
# 0  1   3     4    2.0
# 1  2   4     6    3.0
# 2  7  21    28   14.0

# %%
data = [['tom', 10], ['nick', 15], ['juli', 14]]
df = pd.DataFrame(data, columns = ['Name', 'Age'])
df
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
data = [
        ['Flash Gordon', 1934],
        ['Mandrake', 1934],
        ['Popeye', 1929],
        ['Archie Andrews', 1941],
        ]
df = pd.DataFrame(data, columns = ['name', 'publication_year']) 
df
# Out:
#              name  publication_year
# 0    Flash Gordon              1934
# 1        Mandrake              1934
# 2          Popeye              1929
# 3  Archie Andrews              1941

# %%
df = pd.DataFrame({
        'label': ['A', 'B', 'C', 'A', 'B', 'C'],
        'value': [1, 2, 3, 4, 5, 6],
        })
df
# Out:
#   label  value
# 0     A      1
# 1     B      2
# 2     C      3
# 3     A      4
# 4     B      5
# 5     C      6

# %%
ts = pd.Series(
        np.random.randn(1000),
        index=pd.date_range('1/1/2026', periods=1000),
        )
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('http://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv')

# %%
df.sample(6)
# Out:
#      Survived  Pclass                                               Name  \
# 445         1       3                      Miss. Marie Catherine Baclini
# 718         0       2                        Mr. William Henry Gillespie
# 354         1       1                         Miss. Elsie Edith Bowerman
# 317         1       1  Mrs. Frederic Oakley (Margaretta Corning Stone...
# 131         0       3      Mrs. Alexander A (Grace Charity Laury) Robins
# 379         1       3                                  Miss. Maria Nakid
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# 445  female   5.0                        2                        1   19.2583
# 718    male  34.0                        0                        0   13.0000
# 354  female  22.0                        0                        1   55.0000
# 317  female  40.0                        1                        1  134.5000
# ...

# %%
df['Pclass'].plot()
# Out:
# <Axes: >

# %%
url = "https://en.wikipedia.org/wiki/Minnesota"
tables = pd.read_html(url)
print(len(tables))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 url = "https://en.wikipedia.org/wiki/Minnesota"
# ----> 2 tables = pd.read_html(url)
#       3 print(len(tables))
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/html.py:1226, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1222 check_dtype_backend(dtype_backend)
#    1224 io = stringify_path(io)
# -> 1226 return _parse(
#    1227     flavor=flavor,
#    1228     io=io,
#    1229     match=match,
#    1230     header=header,
#    1231     index_col=index_col,
#    1232     skiprows=skiprows,
#    1233     parse_dates=parse_dates,
#    1234     thousands=thousands,
#    1235     attrs=attrs,
#    1236     encoding=encoding,
# ...
